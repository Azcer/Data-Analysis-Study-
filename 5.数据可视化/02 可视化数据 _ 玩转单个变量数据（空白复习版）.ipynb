# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 导入本节示例数据，注意此文件并非本地数据文件，而是从Seaborn库里导入的
# Seaborn库里的所有数据可以在这里查看：https://github.com/mwaskom/seaborn-data
# 如果遇到导入问题，可以从以上GitHub仓库下载到本地，然后读取文件
# 或者是参考https://blog.csdn.net/weixin_51755670/article/details/127979895
df1 = pd.read_csv("penguins.csv").query('species == "Adelie"')
s1 = df1['culmen_length_mm']
s1
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 147    36.6
# 148    36.0
# 149    37.8
# 150    36.0
# 151    41.5
# Name: culmen_length_mm, Length: 152, dtype: float64

# %% [markdown]
# ## 对Series进行绘图

# %%
# 把s1绘制为直方图
sns.histplot(s1)
plt.show()

# %%
# 把s1绘制为密度图
sns.kdeplot(s1)
plt.show()

# %%
# 把s1绘制为箱型图

sns.boxplot(s1)
plt.show()

# %%
# 把s1绘制为小提琴图

sns.violinplot(s1)
plt.show()

# %% [markdown]
# ## 对DataFrame进行绘图

# %%
df1

# %%
# 把df1的"culmen_length_mm"列绘制为直方图
sns.histplot(df1, x='culmen_length_mm')
plt.show()

# %% [markdown]
# ## 给图表添加标题和轴标签

# %% [markdown]
# 注意：Matplotlib当前默认的字体并不支持中文展示，所以我们需要把字体换成其它支持中文的字体。
# 由于每台电脑上有的字体并不系统，你可以先查询当前系统所有字体，然后把字体替换成其中某个支持中文的字体。

# %%
# 查询当前系统所有字体
import matplotlib
from matplotlib.font_manager import FontManager

mpl_fonts = set(f.name for f in FontManager().ttflist)
for f in sorted(mpl_fonts):
    print(f)
# Out:
# .ADT Slab Numeric
# .ADT Slab Time
# .Helvetica Neue Interface
# .Hiragino Kaku Gothic Interface
# .Keycaps
# .Keycaps Pad
# .Lock Clock
# .New York
# .PhoneFallback
# .PhoneKeyCaps
# .PhonepadTwo
# .SF Arabic
# .SF Arabic Rounded
# .SF Armenian
# .SF Armenian Rounded
# .SF Camera
# .SF Compact
# .SF Compact Rounded
# .SF Compact Soft
# .SF Georgian
# .SF Georgian Rounded
# .SF Hebrew
# .SF Hebrew Rounded
# .SF UI Mono
# .SF UI Rounded
# .SF UI Soft
# .SF UI Symbols
# .ThonburiUI
# Academy Engraved LET
# Al Nile
# American Typewriter
# Apple SD Gothic Neo
# Apple Symbols
# Arial
# Arial Hebrew
# Arial Rounded MT Bold
# Asphalt
# Athelas
# Avenir
# Avenir Next
# Avenir Next Condensed
# Balega
# Baskerville
# Bebas Neue
# Bodoni 72
# Bodoni 72 Oldstyle
# Bodoni 72 Smallcaps
# Bodoni Ornaments
# Bradley Hand
# Carlito
# Chalkboard SE
# Chalkduster
# Charter
# Cochin
# Copperplate
# Courier
# Courier New
# DB LCD Temp
# DIN Alternate
# DIN Condensed
# Damascus
# Dear Joe Four
# DejaVu Sans
# DejaVu Sans Display
# DejaVu Sans Mono
# DejaVu Serif
# DejaVu Serif Display
# Devanagari Sangam MN
# Didot
# Druk
# Euphemia UCAS
# Fakt Slab Stencil Pro
# Farah
# Futura
# Galvji
# Geeza Pro
# Georgia
# Gill Sans
# Helvetica
# Helvetica Neue
# Hiragino Maru Gothic Pro
# Hiragino Mincho ProN
# Hoefler Text
# Impact
# Iowan Old Style
# Journal Sans New
# Kailasa
# Kefa
# Khmer Sangam MN
# Kohinoor Bangla
# Kohinoor Devanagari
# Kohinoor Gujarati
# Kohinoor Telugu
# Lao Sangam MN
# Malayalam Sangam MN
# Marion
# Marker Felt
# Menlo
# Mishafi
# Mukta Mahee
# Myanmar Sangam MN
# Noteworthy
# Noto Nastaliq Urdu
# Noto Sans Adlam
# Noto Sans Armenian
# Noto Sans Avestan
# Noto Sans Bamum
# Noto Sans Bassa Vah
# Noto Sans Batak
# Noto Sans Bhaiksuki
# Noto Sans Brahmi
# Noto Sans Buginese
# Noto Sans Buhid
# Noto Sans Canadian Aboriginal
# Noto Sans Carian
# Noto Sans Caucasian Albanian
# Noto Sans Chakma
# Noto Sans Cham
# Noto Sans Coptic
# Noto Sans Cuneiform
# Noto Sans Cypriot
# Noto Sans Duployan
# Noto Sans Egyptian Hieroglyphs
# Noto Sans Elbasan
# Noto Sans Glagolitic
# Noto Sans Gothic
# Noto Sans Gunjala Gondi
# Noto Sans Hanifi Rohingya
# Noto Sans Hanunoo
# Noto Sans Hatran
# Noto Sans Imperial Aramaic
# Noto Sans Inscriptional Pahlavi
# Noto Sans Inscriptional Parthian
# Noto Sans Javanese
# Noto Sans Kaithi
# Noto Sans Kannada
# Noto Sans Kayah Li
# Noto Sans Kharoshthi
# Noto Sans Khojki
# Noto Sans Khudawadi
# Noto Sans Lepcha
# Noto Sans Limbu
# Noto Sans Linear A
# Noto Sans Linear B
# Noto Sans Lisu
# Noto Sans Lycian
# Noto Sans Lydian
# Noto Sans Mahajani
# Noto Sans Mandaic
# Noto Sans Manichaean
# Noto Sans Marchen
# Noto Sans Masaram Gondi
# Noto Sans Meetei Mayek
# Noto Sans Mende Kikakui
# Noto Sans Meroitic
# Noto Sans Miao
# Noto Sans Modi
# Noto Sans Mongolian
# Noto Sans Mro
# Noto Sans Multani
# Noto Sans Myanmar
# Noto Sans NKo
# Noto Sans Nabataean
# Noto Sans New Tai Lue
# Noto Sans Newa
# Noto Sans Ol Chiki
# Noto Sans Old Hungarian
# Noto Sans Old Italic
# Noto Sans Old North Arabian
# Noto Sans Old Permic
# Noto Sans Old Persian
# Noto Sans Old South Arabian
# Noto Sans Old Turkic
# Noto Sans Oriya
# Noto Sans Osage
# Noto Sans Osmanya
# Noto Sans Pahawh Hmong
# Noto Sans Palmyrene
# Noto Sans Pau Cin Hau
# Noto Sans PhagsPa
# Noto Sans Phoenician
# Noto Sans Psalter Pahlavi
# Noto Sans Rejang
# Noto Sans Samaritan
# Noto Sans Saurashtra
# Noto Sans Sharada
# Noto Sans Siddham
# Noto Sans Sora Sompeng
# Noto Sans Sundanese
# Noto Sans Syloti Nagri
# Noto Sans Syriac
# Noto Sans Tagalog
# Noto Sans Tagbanwa
# Noto Sans Tai Le
# Noto Sans Tai Tham
# Noto Sans Tai Viet
# Noto Sans Takri
# Noto Sans Thaana
# Noto Sans Tifinagh
# Noto Sans Tirhuta
# Noto Sans Ugaritic
# Noto Sans Vai
# Noto Sans Wancho
# Noto Sans Warang Citi
# Noto Sans Yi
# Noto Serif Ahom
# Noto Serif Balinese
# Noto Serif Hmong Nyiakeng
# Noto Serif Yezidi
# Optima
# Palatino
# Papyrus
# Party LET
# PingFang HK
# Rockwell
# STIX Two Math
# STIX Two Text
# STIXGeneral
# STIXNonUnicode
# STIXSizeFiveSym
# STIXSizeFourSym
# STIXSizeOneSym
# STIXSizeThreeSym
# STIXSizeTwoSym
# Savoye LET
# Scheme
# Seravek
# SignPainter
# Sinhala Sangam MN
# Snell Roundhand
# Sukhumvit Set
# Superclarendon
# Symbol
# System Font
# Tamil Sangam MN
# The Hand Serif
# Thonburi
# Times New Roman
# Trebuchet MS
# Verdana
# Zapf Dingbats
# Zapfino
# cmb10
# cmex10
# cmmi10
# cmr10
# cmss10
# cmsy10
# cmtt10

# %%
# 替换成Heiti TC字体（你的系统上不一定有这个字体，如果没有的`话需要替换成其它的）
matplotlib.rc("font",family='Arial')

# %%
# 把df1的"bill_length_mm"列绘制为直方图
# 把图表标题设置为“Adelie企鹅样本的嘴长度分布”
# 把图表的X轴标签设置为“嘴长度（单位：mm）”
# 把图表的Y轴标签设置为“样本数量”
sns.histplot(df1, x='culmen_length_mm')
plt.title('Adelie')
plt.xlabel('Mouth length(mm)')
plt.ylabel('Sample size')
plt.show()
