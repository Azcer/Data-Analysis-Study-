# %%
import pandas as pd

# %%
pd.read_csv("./amazon.csv").head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
pd.set_option("display.max_columns",150)#设置展示最大列数
pd.set_option("display.max_colwidth",150)#设置每项数据最大显示字符
players = pd.read_csv("./fifa_players.csv",index_col="player_id").head()#index_col设置索引
players.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7896\4195089836.py:3: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv("./fifa_players.csv",index_col="player_id").head()
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
#
#            fifa_update fifa_update_date         short_name  \
# player_id
# 158023               2       2014-09-18           L. Messi
# 20801                2       2014-09-18  Cristiano Ronaldo
# 9014                 2       2014-09-18          A. Robben
# ...

# %%
players.tail()#显示尾部几行数据
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
#
#            fifa_update fifa_update_date         short_name  \
# player_id
# 158023               2       2014-09-18           L. Messi
# 20801                2       2014-09-18  Cristiano Ronaldo
# 9014                 2       2014-09-18          A. Robben
# 41236                2       2014-09-18     Z. Ibrahimović
# 167495               2       2014-09-18           M. Neuer
#
#                                      long_name player_positions  overall  \
# player_id
# ...

# %%
pd.read_csv("./fifa_players (no header).csv",header=None).head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7896\2884924665.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("./fifa_players (no header).csv",header=None).head()
#       0                                                 1    2    3    \
# 0  158023                /player/158023/lionel-messi/150002   15    2
# 1   20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002   15    2
# 2    9014                  /player/9014/arjen-robben/150002   15    2
# 3   41236           /player/41236/zlatan-ibrahimovic/150002   15    2
# 4  167495                /player/167495/manuel-neuer/150002   15    2
#
#           4                  5                                    6    \
# 0  2014-09-18           L. Messi       Lionel Andrés Messi Cuccittini
# 1  2014-09-18  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2  2014-09-18          A. Robben                         Arjen Robben
# ...
